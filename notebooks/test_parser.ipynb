# %%
# notebooks/test_parser.ipynb

import sys
from pathlib import Path

# Add project root to Python path
project_root = Path.cwd().parent  # Go up one directory from notebooks/
sys.path.insert(0, str(project_root))



# Now imports will work
from src.ingestion.parser import DocumentParser, parse_document

# Initialize parser
parser = DocumentParser()

# Test with text file
print("=" * 60)
print("Testing Text File Parser")
print("=" * 60)

text, metadata = parser.parse("../tests/test_documents/sample.txt")

print(f"Document: {metadata['filename']}")
print(f"Size: {metadata['file_size']} bytes")
print(f"Lines: {metadata['num_lines']}")
print(f"\nFirst 500 characters:")
print(text[:500])
# Out:
# INFO:src.ingestion.parser:Parsing text file: sample.txt
# INFO:src.ingestion.parser:✅ Parsed text file: 15 lines, 802 characters
# ...
# Testing Text File Parser
# ...
# Document: sample.txt
# Size: 816 bytes
# Lines: 15
#
# First 500 characters:
# Introduction to RAG Systems
#
# Retrieval-Augmented Generation (RAG) is a technique that combines information retrieval with text generation. The key insight is that large language models can produce more accurate and factual responses when they have access to relevant context from a knowledge base.
#
# How RAG Works
#
# 1. Query Processing: The user's question is converted into an embedding vector.
# 2. Retrieval: Similar documents are found using vector similarity search.
# 3. Generation: The LLM generates
